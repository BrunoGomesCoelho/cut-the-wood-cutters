# %% [markdown]
# # This notebook creates the species correlation matrix, as part of the

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("graph.csv")#, sep=";")
df.head()
# Out:
# /home/bcoelho/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20,21,22,23,36,37,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    numero_serie_dof  especie_agrupada       produto_agrupado        id  \
# 0          15412747  Angelim vermelho  Madeira serrada bruta  23878938
# 1          15412749     Angelim pedra  Madeira serrada bruta  23939726
# 2          15412753          cedrinho                   Tora  23925532
# 3          15412772           Cupiúba                   Tora  24317350
# 4          15412774           Cupiúba                   Tora  24034811
#
#                            nome_remetente   cpf_remetente uf_origem  \
# 0  MADEIREIRA LEAL IND COM IMP E EXP LTDA  07665333000189        RO
# 1                 MADEIREIRA TANGARÁ LTDA  09168412000100        RO
# 2       MADEIREIRA TRÊS ESTADOS EIRELI-ME  18114750000150        RO
# 3                                    JMLG     063********        RO
# 4                                    JMLG     063********        RO
#
#   municipio_origem  cd_mun_origem  latitude_origem  longitude_origem  \
# 0          CUJUBIM        1100940        -9.171094        -62.565336
# 1          CUJUBIM        1100940        -9.171094        -62.565336
# 2      PORTO VELHO        1100205        -9.153593        -64.306814
# 3    PIMENTA BUENO        1100189       -11.894469        -60.830388
# 4    PIMENTA BUENO        1100189       -11.894469        -60.830388
#
#    ctf_remetente                           tipo_origem  \
# 0         904677                                 PATIO
# 1        2765843                                 PATIO
# 2        5895338  AUTEX-Exploração em Planos de Manejo
# 3        6087190  AUTEX-Exploração em Planos de Manejo
# 4        6087190  AUTEX-Exploração em Planos de Manejo
#
#                                    nome_patio_origem  numero_serie_autex  \
# 0             MADEIREIRA LEAL IND COM IMP E EXP LTDA                 NaN
# 1       VALIATI & SILVA LTDA - ME MADEIREIRA TANGARÁ                 NaN
# 2  LOTE 55, SETOR B, GB CARACOL, PROJ FUNDIÁRIO A...        2.201505e+09
# 3  lote 26, gleba corumbiara,setor 06- fazenda Pi...        2.201506e+09
# 4  lote 26, gleba corumbiara,setor 06- fazenda Pi...        2.201506e+09
#
#   numero_autorizacao_original                            tipo_autex  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                    313/2015  AUTEX-Exploração em Planos de Manejo
# 3                    346/2015  AUTEX-Exploração em Planos de Manejo
# 4                    346/2015  AUTEX-Exploração em Planos de Manejo
#
#                                  orgao_emissor_autex dt_validade_autex  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2  Secretaria de Estado do Desenvolvimento Ambien...        12/11/2016
# 3  Secretaria de Estado do Desenvolvimento Ambien...        13/12/2016
# 4  Secretaria de Estado do Desenvolvimento Ambien...        13/12/2016
#
#    numero_di orgao_emissor_di dt_validade_di nome_porto_entrada pais_origem  \
# 0        NaN              NaN            NaN                NaN         NaN
# 1        NaN              NaN            NaN                NaN         NaN
# 2        NaN              NaN            NaN                NaN         NaN
# 3        NaN              NaN            NaN                NaN         NaN
# 4        NaN              NaN            NaN                NaN         NaN
#
#    numero_autesp       ...        ctf_destinatario  \
# 0            NaN       ...               6031951.0
# 1            NaN       ...               6210029.0
# 2            NaN       ...                582757.0
# 3            NaN       ...               5778602.0
# 4            NaN       ...               5778602.0
#
#                                  nome_patio_destino nome_porto_saida_pais  \
# 0                        MADEIREIRA OLIVEIRA - SEDE                   NaN
# 1         BRUNO FABIANO CAVALCANTE (393.988.178-37)                   NaN
# 2  IND COM E EXPORTAÇÃO DE MADEIRAS HOFSTETTER LTDA                   NaN
# 3                 MADEIREIRA SANTA MARIA LTDA - EPP                   NaN
# 4                 MADEIREIRA SANTA MARIA LTDA - EPP                   NaN
#
#   municipio_porto_destino  uf_porto_destino  pais_destino  dt_emissao   ano  \
# 0                     NaN               NaN           NaN  2016-01-01  2016
# 1                     NaN               NaN           NaN  2016-01-01  2016
# 2                     NaN               NaN           NaN  2016-01-01  2016
# 3                     NaN               NaN           NaN  2016-01-01  2016
# 4                     NaN               NaN           NaN  2016-01-01  2016
#
#   dt_validade_inicial  dt_validade_final ultima_transacao dt_ultima_transacao  \
# 0          2016-01-01         2016-01-15         Recebido          2016-01-22
# 1          2016-01-01         2016-07-01         Impresso          2016-01-01
# 2          2016-01-01         2016-04-01         Recebido          2016-02-01
# 3          2016-01-01         2016-04-01         Recebido          2016-02-01
# 4          2016-01-01         2016-04-01         Recebido          2016-02-01
#
#   numero_oferta codigo_controle_dof  \
# 0    74638942.0    6433622412947227
# 1           NaN    2272426485834868
# 2    74633654.0    8723316871217811
# 3    74625468.0    9386969945514286
# 4    74625468.0    6286339168863424
#
#                                      rota_transporte  \
# 0  CUJUBIM/RO-PORTO VELHO/RO;PORTO VELHO/RO-HUMAI...
# 1                            CUJUBIM/RO-ANDRADINA/SP
# 2                      PORTO VELHO/RO-PORTO VELHO/RO
# 3                PIMENTA BUENO/RO-ESPIGAO D'OESTE/RO
# 4                PIMENTA BUENO/RO-ESPIGAO D'OESTE/RO
#
#                      produto  id_produto_agrupado        nome_cientifico  \
# 0   Madeira serrada (caibro)                   12        Dinizia excelsa
# 1  Madeira serrada (prancha)                   12  Hymenolobium petraeum
# 2                       Tora                    1       Erisma uncinatum
# 3                       Tora                    1          Goupia glabra
# 4                       Tora                    1          Goupia glabra
#
#   nome_popular id_especie_agrupada unidade   volume    valor          src_id  \
# 0      Angelim                 105      M3  12.0210  6030.32  07665333000189
# 1      Angelim                  62      M3  13.0964  8543.07  09168412000100
# 2        Libra                 114      M3  48.6149  1458.45  18114750000150
# 3      Cupiúba                  10      M3  39.7300   993.25         063JMLG
# 4      Cupiúba                  10      M3  19.2700   481.75         063JMLG
#
#            dst_id
# 0  20035685000119
# 1         393BFC3
# 2  06259687000160
# 3  17956918000101
# 4  17956918000101
#
# [5 rows x 59 columns]

# %%
idx = df["id_produto_agrupado"] == 12
b = df.loc[idx].groupby(["cd_mun_origem", "especie_agrupada"])[["volume"]].sum()

# %%
idx.sum() / len(df)
# Out:
# 0.45098698573583673

# %%
#(b.unstack().isna().sum(axis=0) == 0).sum()
(b.unstack().isna().sum(axis=0) == 0).sum()
# Out:
# 0

# %%
b_unst = b.unstack()
cols = b_unst.columns.get_level_values(1).values
b_unst = pd.DataFrame(b_unst.values, columns=cols, index=b_unst.index)

# %%
b_unst.shape
# Out:
# (69, 98)

# %%
percent_nan = (b_unst.isna().sum(axis=0) / b_unst.shape[0]).sort_values(ascending=False)
(b_unst.isna().sum(axis=0) / b_unst.shape[0]).sort_values(ascending=False)
# Out:
# Tuia da China                    0.985507
# Pau sangue                       0.985507
# Aroeira                          0.971014
# Sucupira branca                  0.956522
# Jacarandá                        0.956522
# Araucaria                        0.956522
# Sansão do campo                  0.942029
# Cedro faia                       0.927536
# Angelim rajado                   0.927536
# Seringueira                      0.927536
# Mogno brasileiro                 0.913043
# Catuaba                          0.913043
# Cambará                          0.898551
# Araçás e correlatos              0.884058
# Pau marfim                       0.884058
# Cardeiro                         0.869565
# Teca                             0.869565
# Acapu                            0.855072
# Louro amarelo                    0.840580
# Melancieiro                      0.826087
# Cacau-cupuaçu                    0.826087
# Guarapari                        0.826087
# Assacu                           0.811594
# Guaribu                          0.811594
# Acariquara                       0.811594
# Andiroba                         0.797101
# Angico tataré                    0.797101
# Uxirana                          0.797101
# Cabreúva                         0.797101
# Pau amarelo                      0.782609
#                                    ...
# Cedrorana                        0.231884
# Sucupira                         0.217391
# Angelim amargoso                 0.202899
# Caucho - inharé vermelho         0.202899
# Pequiá                           0.202899
# Imbuias e canelas                0.188406
# cedrinho                         0.173913
# Cerejeira                        0.173913
# Muirapitanga e Amapá             0.173913
# Marupá                           0.173913
# Jitaí e jutaí                    0.173913
# Mandioqueiro                     0.159420
# Espécies mistas não declarada    0.159420
# Fava orelha de macaco            0.144928
# Peroba                           0.130435
# Paricá                           0.130435
# Muiracatiara                     0.130435
# Angelim pedra                    0.115942
# Cedro                            0.101449
# Ipê                              0.086957
# Garapeira                        0.086957
# Cumaru                           0.086957
# Tanimbuca                        0.086957
# Abiu                             0.086957
# Maçaranduba                      0.072464
# Gameleiro                        0.072464
# Outras espécies nativas          0.072464
# Tauari                           0.072464
# Jatobá                           0.057971
# Espécies mistas brancas          0.057971
# Length: 98, dtype: float64

# %%
sns.boxplot(percent_nan)

# %%
print(b_unst.sum(axis=1).isna().sum())
df_norm = pd.DataFrame(b_unst.values / b_unst.sum(axis=1).values[:, None],
                      columns=b_unst.columns, index=b_unst.index)
# Out:
# 0

# %%
df_norm.head()
# Out:
#                    Abiu     Acapu  Acariquara  Aguaí - bacumixá  Amaparana  \
# cd_mun_origem
# 1100015        0.003940       NaN         NaN               NaN        NaN
# 1100023        0.026306  0.000309    0.000081          0.000014   0.002874
# 1100031             NaN       NaN         NaN               NaN        NaN
# 1100049        0.015743       NaN         NaN               NaN   0.001100
# 1100056        0.000508       NaN         NaN               NaN   0.000213
#
#                Andiroba  Angelim amargoso  Angelim pedra  Angelim rajado  \
# cd_mun_origem
# 1100015             NaN          0.006890       0.011418             NaN
# 1100023             NaN          0.008524       0.037359             NaN
# 1100031             NaN          0.003053       0.013415             NaN
# 1100049        0.000062          0.007185       0.035666             NaN
# 1100056             NaN          0.007218       0.038763             NaN
#
#                Angelim vermelho  Angico tataré  Araucaria  \
# cd_mun_origem
# 1100015                     NaN            NaN        NaN
# 1100023                0.049952        0.00002   0.000013
# 1100031                     NaN            NaN        NaN
# 1100049                     NaN            NaN        NaN
# 1100056                0.000291            NaN        NaN
#
#                Araçás e correlatos   Aroeira  Assacu  Açoita cavalo  \
# cd_mun_origem
# 1100015                        NaN  0.005156     NaN       0.004588
# 1100023                        NaN       NaN     NaN       0.001422
# 1100031                        NaN       NaN     NaN            NaN
# 1100049                        NaN       NaN     NaN       0.001500
# 1100056                        NaN       NaN     NaN       0.001234
#
#                Biriba - Matamatá  Cabreúva  Cacau-cupuaçu  Cajus e cajuaçus  \
# cd_mun_origem
# 1100015                 0.000186  0.000502            NaN          0.000381
# 1100023                 0.002336  0.000014       0.000022          0.001131
# 1100031                 0.004823       NaN            NaN               NaN
# 1100049                 0.000285  0.000237            NaN          0.003459
# 1100056                 0.000830       NaN            NaN          0.001250
#
#                   Cajás       Cambará  Canafístula  Cardeiro   Catuaba  \
# cd_mun_origem
# 1100015        0.004171           NaN          NaN       NaN       NaN
# 1100023        0.000031  2.274580e-06     0.000158  0.000037  0.000002
# 1100031             NaN           NaN          NaN       NaN       NaN
# 1100049        0.000044  1.205720e-08     0.000123       NaN       NaN
# 1100056             NaN           NaN     0.000115       NaN       NaN
#
#                  ...     Pau rosa  Pau sangue    Pequiá    Peroba   Quaruba  \
# cd_mun_origem    ...
# 1100015          ...     0.001639         NaN  0.001466  0.024556  0.000278
# 1100023          ...     0.000571         NaN  0.015195  0.001918  0.002592
# 1100031          ...          NaN         NaN  0.033980  0.006725       NaN
# 1100049          ...     0.001997         NaN  0.027658  0.016398  0.001923
# 1100056          ...     0.000899         NaN  0.038865  0.002400  0.002415
#
#                 Roxinho  Sansão do campo  Seringueira  Sucupira  \
# cd_mun_origem
# 1100015             NaN              NaN          NaN  0.008154
# 1100023        0.044316              NaN     0.000027  0.005185
# 1100031             NaN              NaN          NaN  0.003788
# 1100049        0.018062              NaN          NaN  0.003499
# 1100056        0.051290              NaN          NaN  0.003564
#
#                Sucupira branca  Sucupira vermelha     Tachi  Tachi branco  \
# cd_mun_origem
# 1100015                    NaN           0.001157  0.000066           NaN
# 1100023                    NaN           0.000682  0.030737      0.000409
# 1100031                    NaN                NaN  0.008284           NaN
# 1100049                    NaN           0.000016  0.004149      0.000080
# 1100056                    NaN                NaN  0.003575           NaN
#
#                Tamarindo  Tanimbuca  Tatajuba    Tauari      Teca  Timborana  \
# cd_mun_origem
# 1100015         0.000001   0.009827       NaN  0.011819       NaN        NaN
# 1100023         0.000870   0.018790  0.001875  0.286043  0.000079     0.0001
# 1100031              NaN   0.007823       NaN  0.000630       NaN        NaN
# 1100049         0.000320   0.020604  0.011434  0.153579       NaN        NaN
# 1100056         0.001076   0.002991  0.005721  0.056217       NaN        NaN
#
#                Tuia da China      Uchi  Ucuubarana   Uxirana    Virola  \
# cd_mun_origem
# 1100015                  NaN       NaN         NaN       NaN       NaN
# 1100023                  NaN  0.001404    0.002809  0.000007  0.000846
# 1100031                  NaN       NaN         NaN       NaN       NaN
# 1100049                  NaN  0.000144         NaN       NaN       NaN
# 1100056                  NaN       NaN         NaN       NaN       NaN
#
#                cedrinho
# cd_mun_origem
# 1100015        0.057879
# 1100023        0.010618
# 1100031        0.005216
# 1100049        0.033885
# 1100056        0.030254
#
# [5 rows x 98 columns]

# %%
df_norm.corr().isna().sum() == 2
# Out:
# Abiu                         True
# Acapu                       False
# Acariquara                  False
# Aguaí - bacumixá            False
# Amaparana                   False
# Andiroba                    False
# Angelim amargoso             True
# Angelim pedra                True
# Angelim rajado              False
# Angelim vermelho            False
# Angico tataré               False
# Araucaria                   False
# Araçás e correlatos         False
# Aroeira                     False
# Assacu                      False
# Açoita cavalo                True
# Biriba - Matamatá            True
# Cabreúva                    False
# Cacau-cupuaçu               False
# Cajus e cajuaçus             True
# Cajás                       False
# Cambará                     False
# Canafístula                 False
# Cardeiro                    False
# Catuaba                     False
# Caucho - inharé vermelho     True
# Cedro                        True
# Cedro faia                  False
# Cedrorana                    True
# Cerejeira                    True
#                             ...
# Parapará                     True
# Paricá                       True
# Pau amarelo                 False
# Pau marfim                  False
# Pau mulato                  False
# Pau rosa                     True
# Pau sangue                  False
# Pequiá                       True
# Peroba                       True
# Quaruba                      True
# Roxinho                     False
# Sansão do campo             False
# Seringueira                 False
# Sucupira                     True
# Sucupira branca             False
# Sucupira vermelha            True
# Tachi                        True
# Tachi branco                False
# Tamarindo                    True
# Tanimbuca                    True
# Tatajuba                    False
# Tauari                       True
# Teca                        False
# Timborana                   False
# Tuia da China               False
# Uchi                        False
# Ucuubarana                  False
# Uxirana                     False
# Virola                      False
# cedrinho                     True
# Length: 98, dtype: bool

# %%
df_corr = df_norm.corr()
valid = df_corr.isna().sum() == 2
df_corr = df_corr.loc[valid.values, valid[valid].index.values]
df_corr.head()
# Out:
#                        Abiu  Angelim amargoso  Angelim pedra  Açoita cavalo  \
# Abiu               1.000000          0.492333      -0.066043      -0.105779
# Angelim amargoso   0.492333          1.000000       0.196975      -0.094482
# Angelim pedra     -0.066043          0.196975       1.000000      -0.318863
# Açoita cavalo     -0.105779         -0.094482      -0.318863       1.000000
# Biriba - Matamatá -0.148810         -0.387718      -0.371190      -0.177825
#
#                    Biriba - Matamatá  Cajus e cajuaçus  \
# Abiu                       -0.148810          0.002227
# Angelim amargoso           -0.387718         -0.144344
# Angelim pedra              -0.371190         -0.150324
# Açoita cavalo              -0.177825          0.543979
# Biriba - Matamatá           1.000000         -0.042754
#
#                    Caucho - inharé vermelho     Cedro  Cedrorana  Cerejeira  \
# Abiu                               0.480634 -0.098902  -0.075637  -0.036607
# Angelim amargoso                   0.137893 -0.166165   0.225694  -0.159096
# Angelim pedra                     -0.317148 -0.300539   0.263029  -0.375871
# Açoita cavalo                      0.271025  0.062837  -0.185317   0.259443
# Biriba - Matamatá                  0.219002  0.559779  -0.225693   0.499870
#
#                     Copaíba    Cumaru   Cupiúba  Espécies mistas brancas  \
# Abiu              -0.168847 -0.244158 -0.277814                 0.236317
# Angelim amargoso  -0.278360 -0.322769 -0.003335                 0.057119
# Angelim pedra     -0.405921 -0.319920  0.405508                -0.357153
# Açoita cavalo     -0.021285 -0.186351 -0.138024                 0.263969
# Biriba - Matamatá  0.747642  0.530377 -0.086730                 0.196746
#
#                    Espécies mistas não declarada  Farinha seca  \
# Abiu                                    0.180566     -0.086219
# Angelim amargoso                        0.348775      0.089773
# Angelim pedra                           0.008755     -0.361665
# Açoita cavalo                          -0.172926      0.239196
# Biriba - Matamatá                      -0.042052      0.004833
#
#                    Fava orelha de macaco  Gameleiro  Garapeira  Guanandi  \
# Abiu                            0.028251  -0.199084  -0.280595 -0.072206
# Angelim amargoso                0.154337   0.218359  -0.310455  0.129697
# Angelim pedra                  -0.120677  -0.020313   0.099206 -0.095568
# Açoita cavalo                   0.094911  -0.009772   0.076523 -0.061176
# Biriba - Matamatá              -0.155809   0.119481   0.493150 -0.056801
#
#                    Guatambu  Imbuias e canelas       Ipê    Itaúba    Jatobá  \
# Abiu              -0.134661          -0.072727 -0.005406 -0.118418  0.036755
# Angelim amargoso   0.267913           0.016938  0.047744 -0.071767 -0.182512
# Angelim pedra      0.022367          -0.254255  0.182990 -0.091781 -0.192664
# Açoita cavalo      0.016811           0.087715 -0.034959 -0.192504  0.104141
# Biriba - Matamatá -0.015521          -0.253919  0.097204 -0.142249  0.252331
#
#                    Jitaí e jutaí  Louro vermelho  Mandioqueiro    Marupá  \
# Abiu                    0.352634       -0.026690     -0.192768  0.089747
# Angelim amargoso        0.296156        0.187300      0.050244  0.209826
# Angelim pedra           0.013133       -0.183565     -0.052813 -0.007609
# Açoita cavalo          -0.051160       -0.077584      0.075689  0.004873
# Biriba - Matamatá       0.172871       -0.037066     -0.226258 -0.209154
#
#                    Maçaranduba  Morototó  Muiracatiara  Muirapitanga e Amapá  \
# Abiu                 -0.073531  0.341434      0.276442             -0.136018
# Angelim amargoso     -0.185699  0.166841      0.160258             -0.127457
# Angelim pedra         0.171379  0.104184      0.306121             -0.179527
# Açoita cavalo        -0.190584 -0.126787     -0.068097              0.130919
# Biriba - Matamatá    -0.085226 -0.190757     -0.253044              0.176078
#
#                    Outras espécies nativas  Parapará    Paricá  Pau rosa  \
# Abiu                              0.105447  0.008943  0.002729  0.116471
# Angelim amargoso                 -0.031607  0.134901  0.012650 -0.025360
# Angelim pedra                    -0.372009 -0.285969 -0.216196 -0.097078
# Açoita cavalo                     0.301280  0.097002  0.117544 -0.210177
# Biriba - Matamatá                -0.069532 -0.081368 -0.251443 -0.090183
#
#                      Pequiá    Peroba   Quaruba  Sucupira  Sucupira vermelha  \
# Abiu              -0.148012 -0.147892 -0.045794 -0.099121           0.198260
# Angelim amargoso  -0.260635 -0.034270 -0.038972  0.092506           0.379920
# Angelim pedra      0.001575 -0.418127 -0.042055  0.198306          -0.113228
# Açoita cavalo     -0.041359  0.280974  0.056961 -0.158232          -0.147089
# Biriba - Matamatá -0.093819  0.056147 -0.175911 -0.321459          -0.092484
#
#                       Tachi  Tamarindo  Tanimbuca    Tauari  cedrinho
# Abiu               0.144347   0.030633   0.286413 -0.013326 -0.093973
# Angelim amargoso   0.029642   0.266516   0.009430  0.060059  0.205115
# Angelim pedra     -0.042268   0.028517  -0.125168  0.383609  0.078900
# Açoita cavalo      0.142332   0.266329   0.122064 -0.162763 -0.114798
# Biriba - Matamatá -0.100165  -0.151960  -0.253230 -0.221972 -0.232416

# %%
df_corr.isna().sum().sum()
# Out:
# 0

# %%
df_corr.shape
# Out:
# (47, 47)

# %%
df_corr = (df_corr + 1) / 2

# %%
wanted_species = df_corr.columns
df_corr.head()
# Out:
#                        Abiu  Angelim amargoso  Angelim pedra  Açoita cavalo  \
# Abiu               1.000000          0.746166       0.466979       0.447110
# Angelim amargoso   0.746166          1.000000       0.598488       0.452759
# Angelim pedra      0.466979          0.598488       1.000000       0.340568
# Açoita cavalo      0.447110          0.452759       0.340568       1.000000
# Biriba - Matamatá  0.425595          0.306141       0.314405       0.411088
#
#                    Biriba - Matamatá  Cajus e cajuaçus  \
# Abiu                        0.425595          0.501113
# Angelim amargoso            0.306141          0.427828
# Angelim pedra               0.314405          0.424838
# Açoita cavalo               0.411088          0.771990
# Biriba - Matamatá           1.000000          0.478623
#
#                    Caucho - inharé vermelho     Cedro  Cedrorana  Cerejeira  \
# Abiu                               0.740317  0.450549   0.462182   0.481696
# Angelim amargoso                   0.568946  0.416918   0.612847   0.420452
# Angelim pedra                      0.341426  0.349730   0.631514   0.312064
# Açoita cavalo                      0.635512  0.531418   0.407342   0.629722
# Biriba - Matamatá                  0.609501  0.779890   0.387154   0.749935
#
#                     Copaíba    Cumaru   Cupiúba  Espécies mistas brancas  \
# Abiu               0.415576  0.377921  0.361093                 0.618158
# Angelim amargoso   0.360820  0.338615  0.498333                 0.528559
# Angelim pedra      0.297040  0.340040  0.702754                 0.321423
# Açoita cavalo      0.489358  0.406824  0.430988                 0.631984
# Biriba - Matamatá  0.873821  0.765189  0.456635                 0.598373
#
#                    Espécies mistas não declarada  Farinha seca  \
# Abiu                                    0.590283      0.456891
# Angelim amargoso                        0.674388      0.544887
# Angelim pedra                           0.504377      0.319167
# Açoita cavalo                           0.413537      0.619598
# Biriba - Matamatá                       0.478974      0.502416
#
#                    Fava orelha de macaco  Gameleiro  Garapeira  Guanandi  \
# Abiu                            0.514125   0.400458   0.359702  0.463897
# Angelim amargoso                0.577168   0.609179   0.344772  0.564848
# Angelim pedra                   0.439661   0.489843   0.549603  0.452216
# Açoita cavalo                   0.547455   0.495114   0.538262  0.469412
# Biriba - Matamatá               0.422095   0.559741   0.746575  0.471599
#
#                    Guatambu  Imbuias e canelas       Ipê    Itaúba    Jatobá  \
# Abiu               0.432669           0.463637  0.497297  0.440791  0.518377
# Angelim amargoso   0.633957           0.508469  0.523872  0.464117  0.408744
# Angelim pedra      0.511183           0.372873  0.591495  0.454110  0.403668
# Açoita cavalo      0.508405           0.543857  0.482521  0.403748  0.552070
# Biriba - Matamatá  0.492239           0.373041  0.548602  0.428875  0.626165
#
#                    Jitaí e jutaí  Louro vermelho  Mandioqueiro    Marupá  \
# Abiu                    0.676317        0.486655      0.403616  0.544874
# Angelim amargoso        0.648078        0.593650      0.525122  0.604913
# Angelim pedra           0.506566        0.408217      0.473594  0.496196
# Açoita cavalo           0.474420        0.461208      0.537844  0.502437
# Biriba - Matamatá       0.586436        0.481467      0.386871  0.395423
#
#                    Maçaranduba  Morototó  Muiracatiara  Muirapitanga e Amapá  \
# Abiu                  0.463235  0.670717      0.638221              0.431991
# Angelim amargoso      0.407150  0.583420      0.580129              0.436271
# Angelim pedra         0.585690  0.552092      0.653060              0.410236
# Açoita cavalo         0.404708  0.436606      0.465951              0.565459
# Biriba - Matamatá     0.457387  0.404621      0.373478              0.588039
#
#                    Outras espécies nativas  Parapará    Paricá  Pau rosa  \
# Abiu                              0.552724  0.504471  0.501364  0.558236
# Angelim amargoso                  0.484197  0.567451  0.506325  0.487320
# Angelim pedra                     0.313995  0.357015  0.391902  0.451461
# Açoita cavalo                     0.650640  0.548501  0.558772  0.394912
# Biriba - Matamatá                 0.465234  0.459316  0.374278  0.454909
#
#                      Pequiá    Peroba   Quaruba  Sucupira  Sucupira vermelha  \
# Abiu               0.425994  0.426054  0.477103  0.450440           0.599130
# Angelim amargoso   0.369683  0.482865  0.480514  0.546253           0.689960
# Angelim pedra      0.500787  0.290937  0.478973  0.599153           0.443386
# Açoita cavalo      0.479321  0.640487  0.528481  0.420884           0.426455
# Biriba - Matamatá  0.453091  0.528074  0.412044  0.339271           0.453758
#
#                       Tachi  Tamarindo  Tanimbuca    Tauari  cedrinho
# Abiu               0.572174   0.515316   0.643207  0.493337  0.453013
# Angelim amargoso   0.514821   0.633258   0.504715  0.530030  0.602557
# Angelim pedra      0.478866   0.514258   0.437416  0.691805  0.539450
# Açoita cavalo      0.571166   0.633165   0.561032  0.418619  0.442601
# Biriba - Matamatá  0.449918   0.424020   0.373385  0.389014  0.383792

# %%
log_volume = np.log10(b_unst.sum(axis=0))[wanted_species]

# %% [markdown]
# # Create csv files

# %%
df_nodes = pd.DataFrame()
df_nodes["Id"] = wanted_species
df_nodes["Label"] = wanted_species
df_nodes["LogTotVol"] = log_volume.values

df_nodes.to_csv("nodes.csv", index=False)
df_nodes.head()
# Out:
#                   Id              Label  LogTotVol
# 0               Abiu               Abiu   5.405160
# 1   Angelim amargoso   Angelim amargoso   4.933494
# 2      Angelim pedra      Angelim pedra   5.853225
# 3      Açoita cavalo      Açoita cavalo   4.087448
# 4  Biriba - Matamatá  Biriba - Matamatá   4.724788

# %%
idx = ~np.triu(np.ones(df_corr.shape)).astype(np.bool)
df_edges = df_corr.where(idx).stack().reset_index()
df_edges.columns= ["Source", "Target", "Weight"]
df_edges.head()
# Out:
#              Source            Target    Weight
# 0  Angelim amargoso              Abiu  0.746166
# 1     Angelim pedra              Abiu  0.466979
# 2     Angelim pedra  Angelim amargoso  0.598488
# 3     Açoita cavalo              Abiu  0.447110
# 4     Açoita cavalo  Angelim amargoso  0.452759

# %%
df_edges.to_csv("edges.csv", index=False)

# %%
print("hi")
# Out:
# hi
